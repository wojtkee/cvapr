# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Załadowanie danych
dat = pd.read_csv('bigtrain.csv')
data=dat.loc[:,'original_shape_Elongation':]

# %%
corr_matrix=data.corr()

# %%
plt.figure(figsize=(25,25))
sns.heatmap(corr_matrix,cmap='coolwarm')
# plt.show()

# plt.savefig('heatmapV1.png' , dpi=1200)
# Out:
# <AxesSubplot:>

# %%
target_corr=corr_matrix.loc[:,'target']

top_6_val=target_corr.nlargest(6)
print(top_6_val)
# Out:
# target                                                1.000000
# original_glszm_SmallAreaHighGrayLevelEmphasis         0.144157
# original_glszm_HighGrayLevelZoneEmphasis              0.138267
# original_glrlm_HighGrayLevelRunEmphasis               0.134408
# original_gldm_LargeDependenceHighGrayLevelEmphasis    0.134337
# original_glcm_Autocorrelation                         0.128217
# Name: target, dtype: float64
